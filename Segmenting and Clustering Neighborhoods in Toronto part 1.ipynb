# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

# %%
source = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
soup = BeautifulSoup(source,'lxml')

# %%
class TabelParser:

    def parse_url(self,url):
        response = requests.get(url)
        soup = BeautifulSoup(response.text,'lxml')
        return [(self.parse_table(table))\
                    for table in soup.find_all('table', class_="wikitable sortable")]
    def parse_table(self,table):
        n_rows = 0 
        n_columns = 0
        column_name = []
        
        for row in table.find_all('tr'):
            td_tags = row.find_all('td')
            
            if len(td_tags) > 0:
                n_rows += 1
                
                if n_columns == 0:
                    n_columns = len(td_tags)
                    
            th_tags = row.find_all('th')
            if len(th_tags) > 0 and len(column_name) == 0:
                for th in th_tags:
                    column_name.append(th.get_text())
        
        if len(column_name) > 0 and len(column_name) != n_columns:
            raise Exception("Headers do not match the number of columns")
            
        columns = column_name if len(column_name) > 0 else range(0,n_columns)
        df = pd.DataFrame(columns=columns,index = range(0,n_rows))
        
        row_index = 0
        for row in table.find_all('tr'):
            column_index = 0
            columns = row.find_all('td')
            for column in columns:
                df.iat[row_index,column_index] = column.get_text()
                column_index += 1
            if len(columns) > 0:
                row_index += 1
                
        for col in df:
            try:
                df[col] = df[col].astype(float)
            except ValueError:
                pass
            
        return df

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
tp = TabelParser()
df = tp.parse_url(url)[0]
df.head(10)
# Out:
#   Postcode           Borough     Neighbourhood\n
# 0      M1A      Not assigned      Not assigned\n
# 1      M2A      Not assigned      Not assigned\n
# 2      M3A        North York         Parkwoods\n
# 3      M4A        North York  Victoria Village\n
# 4      M5A  Downtown Toronto      Harbourfront\n
# 5      M5A  Downtown Toronto       Regent Park\n
# 6      M6A        North York  Lawrence Heights\n
# 7      M6A        North York    Lawrence Manor\n
# 8      M7A      Queen's Park      Not assigned\n
# 9      M8A      Not assigned      Not assigned\n

# %%
a = df.copy()

# %%
a = a[a.Borough != 'Not assigned']

# %%
a.head()
# Out:
#   Postcode           Borough     Neighbourhood\n
# 2      M3A        North York         Parkwoods\n
# 3      M4A        North York  Victoria Village\n
# 4      M5A  Downtown Toronto      Harbourfront\n
# 5      M5A  Downtown Toronto       Regent Park\n
# 6      M6A        North York  Lawrence Heights\n

# %%
a = a.reset_index().drop(['index'],axis=1)
a = a.replace('\n','',regex=True)

# %%
a.head()
# Out:
#   Postcode           Borough   Neighbourhood\n
# 0      M3A        North York         Parkwoods
# 1      M4A        North York  Victoria Village
# 2      M5A  Downtown Toronto      Harbourfront
# 3      M5A  Downtown Toronto       Regent Park
# 4      M6A        North York  Lawrence Heights

# %%
a.rename(columns={'Neighbourhood\n':'Neighbourhood'},inplace=True)

# %%
a.Neighbourhood[a.Neighbourhood=='Not assigned '] = a.Borough

# %%
a.head(10)
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M3A        North York         Parkwoods
# 1      M4A        North York  Victoria Village
# 2      M5A  Downtown Toronto      Harbourfront
# 3      M5A  Downtown Toronto       Regent Park
# 4      M6A        North York  Lawrence Heights
# 5      M6A        North York    Lawrence Manor
# 6      M7A      Queen's Park      Not assigned
# 7      M9A         Etobicoke  Islington Avenue
# 8      M1B       Scarborough             Rouge
# 9      M1B       Scarborough           Malvern

# %%
df_full = a.groupby(['Postcode','Borough'])['Neighbourhood'].apply(lambda x: ", ".join(x.astype(str))).reset_index()
df_full = df_full.sample(frac=1).reset_index(drop=True)
df_full.head(10)
# Out:
#   Postcode           Borough  \
# 0      M2N        North York
# 1      M1N       Scarborough
# 2      M4C         East York
# 3      M6B        North York
# 4      M5G  Downtown Toronto
# 5      M4W  Downtown Toronto
# 6      M5B  Downtown Toronto
# 7      M5V  Downtown Toronto
# 8      M4B         East York
# 9      M6S      West Toronto
#
#                                        Neighbourhood
# 0                                   Willowdale South
# 1                        Birch Cliff, Cliffside West
# 2                                   Woodbine Heights
# 3                                          Glencairn
# 4                                 Central Bay Street
# 5                                           Rosedale
# 6                           Ryerson, Garden District
# 7  CN Tower, Bathurst Quay, Island airport, Harbo...
# 8                    Woodbine Gardens, Parkview Hill
# 9                                 Runnymede, Swansea

# %%
df_full.shape
# Out:
# (103, 3)

# %%
url = 'http://cocl.us/Geospatial_data'
latlong = pd.read_csv(url)

# %%
latlong.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
latlong.rename(columns={'Postal Code':'Postcode'},inplace=True)

# %%
latlong.head()
# Out:
#   Postcode   Latitude  Longitude
# 0      M1B  43.806686 -79.194353
# 1      M1C  43.784535 -79.160497
# 2      M1E  43.763573 -79.188711
# 3      M1G  43.770992 -79.216917
# 4      M1H  43.773136 -79.239476

# %%
df_full = df_full.merge(latlong,on='Postcode')

# %%
df_full
# Out:
#     Postcode           Borough  \
# 0        M6A        North York
# 1        M1X       Scarborough
# 2        M4J         East York
# 3        M6M              York
# 4        M9M        North York
# 5        M1R       Scarborough
# 6        M6L        North York
# 7        M3B        North York
# 8        M8W         Etobicoke
# 9        M7Y      East Toronto
# 10       M9N              York
# 11       M2P        North York
# 12       M5B  Downtown Toronto
# 13       M4H         East York
# 14       M1L       Scarborough
# 15       M4S   Central Toronto
# 16       M4N   Central Toronto
# 17       M5A  Downtown Toronto
# 18       M1T       Scarborough
# 19       M5L  Downtown Toronto
# 20       M8Z         Etobicoke
# 21       M5E  Downtown Toronto
# 22       M5W  Downtown Toronto
# 23       M1E       Scarborough
# 24       M3M        North York
# 25       M6C              York
# 26       M2R        North York
# 27       M6P      West Toronto
# 28       M1G       Scarborough
# 29       M4P   Central Toronto
# ..       ...               ...
# 73       M5X  Downtown Toronto
# 74       M9P         Etobicoke
# 75       M2N        North York
# 76       M5T  Downtown Toronto
# 77       M4G         East York
# 78       M1N       Scarborough
# 79       M6G  Downtown Toronto
# 80       M4X  Downtown Toronto
# 81       M8X         Etobicoke
# 82       M4Y  Downtown Toronto
# 83       M5V  Downtown Toronto
# 84       M5C  Downtown Toronto
# 85       M5S  Downtown Toronto
# 86       M2K        North York
# 87       M1W       Scarborough
# 88       M8V         Etobicoke
# 89       M9R         Etobicoke
# 90       M2J        North York
# 91       M1K       Scarborough
# 92       M4L      East Toronto
# 93       M9W         Etobicoke
# 94       M6E              York
# 95       M6K      West Toronto
# 96       M9C         Etobicoke
# 97       M5K  Downtown Toronto
# 98       M4E      East Toronto
# 99       M3L        North York
# 100      M7R       Mississauga
# 101      M1V       Scarborough
# 102      M1S       Scarborough
#
#                                          Neighbourhood
# 0                     Lawrence Heights, Lawrence Manor
# 1                                          Upper Rouge
# 2                                         East Toronto
# 3       Del Ray, Keelesdale, Mount Dennis, Silverthorn
# 4                                     Emery, Humberlea
# 5                                    Maryvale, Wexford
# 6                   Downsview, North Park, Upwood Park
# 7                                      Don Mills North
# 8                               Alderwood, Long Branch
# 9    Business Reply Mail Processing Centre 969 Eastern
# 10                                              Weston
# 11                                     York Mills West
# 12                            Ryerson, Garden District
# 13                                    Thorncliffe Park
# 14                     Clairlea, Golden Mile, Oakridge
# 15                                          Davisville
# 16                                       Lawrence Park
# 17                           Harbourfront, Regent Park
# 18             Clarks Corners, Sullivan, Tam O'Shanter
# 19                      Commerce Court, Victoria Hotel
# 20   Kingsway Park South West, Mimico NW, The Queen...
# 21                                         Berczy Park
# 22                     Stn A PO Boxes 25 The Esplanade
# 23                   Guildwood, Morningside, West Hill
# 24                                   Downsview Central
# 25                                  Humewood-Cedarvale
# 26                                     Willowdale West
# 27                       High Park, The Junction South
# 28                                              Woburn
# 29                                    Davisville North
# ..                                                 ...
# 73              First Canadian Place, Underground city
# 74                                           Westmount
# 75                                    Willowdale South
# 76           Chinatown, Grange Park, Kensington Market
# 77                                             Leaside
# 78                         Birch Cliff, Cliffside West
# 79                                            Christie
# 80                         Cabbagetown, St. James Town
# 81       The Kingsway, Montgomery Road, Old Mill North
# 82                                Church and Wellesley
# 83   CN Tower, Bathurst Quay, Island airport, Harbo...
# 84                                      St. James Town
# 85                      Harbord, University of Toronto
# 86                                     Bayview Village
# 87                                     L'Amoreaux West
# 88        Humber Bay Shores, Mimico South, New Toronto
# 89   Kingsview Village, Martin Grove Gardens, Richv...
# 90                        Fairview, Henry Farm, Oriole
# 91         East Birchmount Park, Ionview, Kennedy Park
# 92                      The Beaches West, India Bazaar
# 93                                           Northwest
# 94                                 Caledonia-Fairbanks
# 95        Brockton, Exhibition Place, Parkdale Village
# 96   Bloordale Gardens, Eringate, Markland Wood, Ol...
# 97            Design Exchange, Toronto Dominion Centre
# 98                                         The Beaches
# 99                                      Downsview West
# 100              Canada Post Gateway Processing Centre
# 101  Agincourt North, L'Amoreaux East, Milliken, St...
# 102                                          Agincourt
#
# [103 rows x 3 columns]
